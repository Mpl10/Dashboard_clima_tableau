# %%
import pandas as pd
import requests

# %%
url = "https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/2019-05-01T00%3A00%3A00UTC/fechafin/2019-05-10T23%3A59%3A59UTC/todasestaciones"

querystring = {"api_key":"eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJtaXJpYW1wYXJhbWlvbG9yZW56b0BnbWFpbC5jb20iLCJqdGkiOiI3MGJiNTNhNi00MDc2LTRkOTMtYTU4NS0yOGUxODE3N2FlNTAiLCJpc3MiOiJBRU1FVCIsImlhdCI6MTY3NTc2MTU3MywidXNlcklkIjoiNzBiYjUzYTYtNDA3Ni00ZDkzLWE1ODUtMjhlMTgxNzdhZTUwIiwicm9sZSI6IiJ9.BmatkYSBB3Hz4EN0TtNKDsl6MIA7buec5SFLrLJXBy8"}

headers = {
    'cache-control': "no-cache"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#   "descripcion" : "exito",
#   "estado" : 200,
#   "datos" : "https://opendata.aemet.es/opendata/sh/b8f04fec",
#   "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"
# }

# %%
res = requests.get("https://opendata.aemet.es/opendata/sh/b8f04fec")
response_j = res.json()

# %%
df_prueba=pd.DataFrame(response_j)
df_prueba
# Out:
#            fecha indicativo                     nombre              provincia  \
# 0     2019-05-01      4358X                 DON BENITO                BADAJOZ
# 1     2019-05-01      4220X      PUEBLA DE DON RODRIGO            CIUDAD REAL
# 2     2019-05-01      C447A  TENERIFE NORTE AEROPUERTO  STA. CRUZ DE TENERIFE
# 3     2019-05-01      6106X                  ANTEQUERA                 MALAGA
# 4     2019-05-01      9698U                     TALARN                 LLEIDA
# ...          ...        ...                        ...                    ...
# 2481  2019-05-10      9573X                    ALCAÑIZ                 TERUEL
# 2482  2019-05-10       8416                   VALÈNCIA               VALENCIA
# 2483  2019-05-10      7119B        CARAVACA DE LA CRUZ                 MURCIA
# 2484  2019-05-10      0255B              SANTA SUSANNA              BARCELONA
# 2485  2019-05-10      5612B       LA RODA DE ANDALUCÍA                SEVILLA
#
# ...

# %%
df_prueba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2486 entries, 0 to 2485
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   fecha        2486 non-null   object
#  1   indicativo   2486 non-null   object
#  2   nombre       2486 non-null   object
#  3   provincia    2486 non-null   object
#  4   altitud      2486 non-null   object
#  5   tmed         2441 non-null   object
#  6   prec         2414 non-null   object
#  7   tmin         2441 non-null   object
#  8   horatmin     2409 non-null   object
#  9   tmax         2443 non-null   object
#  10  horatmax     2409 non-null   object
#  11  dir          2331 non-null   object
#  12  velmedia     2360 non-null   object
#  13  racha        2331 non-null   object
#  14  horaracha    2331 non-null   object
#  15  sol          1393 non-null   object
#  16  presMax      1836 non-null   object
#  17  horaPresMax  1836 non-null   object
# ...

# %%
YYYYMM_list=[]
for y in range(2022,2023):
    for m in range(1,13):
        if m<10:
            YYYYMM_list.append(f"{y}-0{m}")
        else:
            YYYYMM_list.append(f"{y}-{m}")

# %%
#Lista de fechas para la llamada
YYYYMM_list=[]
for y in range(2000,2001):
    for m in range(1,13):
        if m<10:
            YYYYMM_list.append(f"{y}-0{m}")
        else:
            YYYYMM_list.append(f"{y}-{m}")

# %%
#Lista de url
url_list=[]

for YYYYMM in YYYYMM_list:
    
    url = f"https://opendata.aemet.es/opendata/api/valores/climatologicos/diarios/datos/fechaini/{YYYYMM}-01T00%3A00%3A00UTC/fechafin/{YYYYMM}-31T23%3A59%3A59UTC/todasestaciones"
    
    querystring = {"api_key":"eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJtaXJpYW1wYXJhbWlvbG9yZW56b0BnbWFpbC5jb20iLCJqdGkiOiI3MGJiNTNhNi00MDc2LTRkOTMtYTU4NS0yOGUxODE3N2FlNTAiLCJpc3MiOiJBRU1FVCIsImlhdCI6MTY3NTc2MTU3MywidXNlcklkIjoiNzBiYjUzYTYtNDA3Ni00ZDkzLWE1ODUtMjhlMTgxNzdhZTUwIiwicm9sZSI6IiJ9.BmatkYSBB3Hz4EN0TtNKDsl6MIA7buec5SFLrLJXBy8"}
    
    headers = {
        'cache-control': "no-cache"
        }
    
    response = requests.request("GET", url, headers=headers, params=querystring)
    
    if response.status_code == 200:
        url_clean=((response.text).split(" "))[12].replace(",\n", "").replace('"', "")
        url_list.append(url_clean)
        print(YYYYMM)
    else:
        print(f"NO {YYYYMM}")
        continue
# Out:
# 2000-01
# 2000-02
# 2000-03
# 2000-04
# 2000-05
# 2000-06
# 2000-07
# 2000-08
# 2000-09
# 2000-10
# 2000-11
# 2000-12

# %%
#Descarga de info.
result = []
for url in url_list:
    try:
        res= requests.get(f"{url}")
        print(url)
        print(res.status_code)
        result.append(res.json())
    except:
        pass

# %%
#construcción df
df_ini=pd.DataFrame([r for d in result for r in d])

# %%
df_ini.duplicated().sum()
# Out:
# 1028

# %%
df_def= df_ini.drop_duplicates()

# %%
df_def.duplicated().sum()
# Out:
# 0

# %%
#csv anual guardado
df_def.to_csv('Climatic_dashboard/Data/AEMET_2000.csv', index = False)

# %%
#concat guardado
df_concat = pd.concat([df2000,
                        df2001,
                        df2002,
                        df2003,
                        df2004,
                        df2005,
                        df2006,
                        df2007,
                        df2008,
                        df2009,
                        df2010,
                        df2011,
                        df2012,
                        df2013,
                        df2014,
                        df2015,
                        df2016,
                        df2017,
                        df2018,
                        df2019,
                        df2020,
                        df2021,
                        df2022,
                        df2023],
axis=0, ignore_index = True)

# %%
df_concat.duplicated().sum()

# %%
df_def["fecha"].unique()
# Out:
# array(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#        '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#        '2000-01-09', '2000-01-10', '2000-01-11', '2000-01-12',
#        '2000-01-13', '2000-01-14', '2000-01-15', '2000-01-16',
#        '2000-01-17', '2000-01-18', '2000-01-19', '2000-01-20',
#        '2000-01-21', '2000-01-22', '2000-01-23', '2000-01-24',
#        '2000-01-25', '2000-01-26', '2000-01-27', '2000-01-28',
#        '2000-01-29', '2000-01-30', '2000-01-31', '2000-02-01',
#        '2000-02-02', '2000-02-03', '2000-02-04', '2000-02-05',
#        '2000-02-06', '2000-02-07', '2000-02-08', '2000-02-09',
#        '2000-02-10', '2000-02-11', '2000-02-12', '2000-02-13',
#        '2000-02-14', '2000-02-15', '2000-02-16', '2000-02-17',
#        '2000-02-18', '2000-02-19', '2000-02-20', '2000-02-21',
#        '2000-02-22', '2000-02-23', '2000-02-24', '2000-02-25',
#        '2000-02-26', '2000-02-27', '2000-02-28', '2000-02-29',
# ...

# %%
df2000= pd.read_csv('Data/AEMET_2000.csv')
df2001= pd.read_csv('Data/AEMET_2001.csv')
df2002= pd.read_csv('Data/AEMET_2002.csv')
df2003= pd.read_csv('Data/AEMET_2003.csv')
df2004= pd.read_csv('Data/AEMET_2004.csv')
df2005= pd.read_csv('Data/AEMET_2005.csv')
df2006= pd.read_csv('Data/AEMET_2006.csv')
df2007= pd.read_csv('Data/AEMET_2007.csv')
df2008= pd.read_csv('Data/AEMET_2008.csv')
df2009= pd.read_csv('Data/AEMET_2009.csv')
df2010= pd.read_csv('Data/AEMET_2010.csv')
df2011= pd.read_csv('Data/AEMET_2011.csv')
df2012= pd.read_csv('Data/AEMET_2012.csv')
df2013= pd.read_csv('Data/AEMET_2013.csv')
df2014= pd.read_csv('Data/AEMET_2014.csv')
df2015= pd.read_csv('Data/AEMET_2015.csv')
df2016= pd.read_csv('Data/AEMET_2016.csv')
df2017= pd.read_csv('Data/AEMET_2017.csv')
df2018= pd.read_csv('Data/AEMET_2018.csv')
df2019= pd.read_csv('Data/AEMET_2019.csv')
df2020= pd.read_csv('Data/AEMET_2020.csv')
df2021= pd.read_csv('Data/AEMET_2021.csv')
df2022= pd.read_csv('Data/AEMET_2022.csv')
df2023= pd.read_csv('Data/AEMET_2023.csv')

# %%
for i in range(2000, 2024):
    print(f"df{i}= pd.read_csv('Data/AEMET_{i}.csv')")
# Out:
# df2000= pd.read_csv('Data/AEMET_2000.csv')
# df2001= pd.read_csv('Data/AEMET_2001.csv')
# df2002= pd.read_csv('Data/AEMET_2002.csv')
# df2003= pd.read_csv('Data/AEMET_2003.csv')
# df2004= pd.read_csv('Data/AEMET_2004.csv')
# df2005= pd.read_csv('Data/AEMET_2005.csv')
# df2006= pd.read_csv('Data/AEMET_2006.csv')
# df2007= pd.read_csv('Data/AEMET_2007.csv')
# df2008= pd.read_csv('Data/AEMET_2008.csv')
# df2009= pd.read_csv('Data/AEMET_2009.csv')
# df2010= pd.read_csv('Data/AEMET_2010.csv')
# df2011= pd.read_csv('Data/AEMET_2011.csv')
# df2012= pd.read_csv('Data/AEMET_2012.csv')
# df2013= pd.read_csv('Data/AEMET_2013.csv')
# df2014= pd.read_csv('Data/AEMET_2014.csv')
# df2015= pd.read_csv('Data/AEMET_2015.csv')
# df2016= pd.read_csv('Data/AEMET_2016.csv')
# df2017= pd.read_csv('Data/AEMET_2017.csv')
# df2018= pd.read_csv('Data/AEMET_2018.csv')
# df2019= pd.read_csv('Data/AEMET_2019.csv')
# df2020= pd.read_csv('Data/AEMET_2020.csv')
# df2021= pd.read_csv('Data/AEMET_2021.csv')
# ...

# %%
for i in range(2000, 2024):
    print(f"df{i},")
# Out:
# df2000,
# df2001,
# df2002,
# df2003,
# df2004,
# df2005,
# df2006,
# df2007,
# df2008,
# df2009,
# df2010,
# df2011,
# df2012,
# df2013,
# df2014,
# df2015,
# df2016,
# df2017,
# df2018,
# df2019,
# df2020,
# df2021,
# df2022,
# df2023,

# %%
df_def.to_csv('Climatic_dashboard/Data/AEMET_2000.csv', index = False)

# %%
df_concat = pd.concat([df2000,
df2001,
df2002,
df2003,
df2004,
df2005,
df2006,
df2007,
df2008,
df2009,
df2010,
df2011,
df2012,
df2013,
df2014,
df2015,
df2016,
df2017,
df2018,
df2019,
df2020,
df2021,
df2022,
df2023], axis=0, ignore_index = True) #False mantiene los índices originales
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1919680 entries, 0 to 1919679
# Data columns (total 20 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   fecha        object
#  1   indicativo   object
#  2   nombre       object
#  3   provincia    object
#  4   altitud      int64
#  5   tmed         object
#  6   prec         object
#  7   tmin         object
#  8   horatmin     object
#  9   tmax         object
#  10  horatmax     object
#  11  dir          float64
#  12  velmedia     object
#  13  racha        object
#  14  horaracha    object
#  15  sol          object
#  16  presMax      object
#  17  horaPresMax  object
#  18  presMin      object
#  19  horaPresMin  object
# dtypes: float64(1), int64(1), object(18)
# memory usage: 292.9+ MB

# %%
respuesta = requests.get(f"{url_test}")
respuesta_j = respuesta.json()

# %%
df = pd.DataFrame()

# %%
len(df)
# Out:
# 0

# %%
x=response.text

# %%
x
# Out:
# '{\n  "descripcion" : "exito",\n  "estado" : 200,\n  "datos" : "https://opendata.aemet.es/opendata/sh/e98280a1",\n  "metadatos" : "https://opendata.aemet.es/opendata/sh/b3aa9d28"\n}'

# %%
z=(x.split(" "))[12].replace(",\n", "").replace('"', "")

# %%
z
# Out:
# 'https://opendata.aemet.es/opendata/sh/e98280a1'

# %%
url_test=z[12].replace(",\n", "").replace('"', "")

# %%
url_test
# Out:
# 'https://opendata.aemet.es/opendata/sh/f98f9155'

# %%
respuesta = requests.get(f"{url_test}")
respuesta_j = respuesta.json()

# %%
prueba_app=[]

# %%
len(respuesta_222)
# Out:
# 30

# %%
df_concat0 = pd.concat([df_prueba_1, respuesta_222], axis=0, ignore_index = True) #False mantiene los índices originales
df_concat0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   fecha       60 non-null     object
#  1   indicativo  60 non-null     object
#  2   nombre      60 non-null     object
#  3   provincia   60 non-null     object
#  4   altitud     60 non-null     object
#  5   tmed        60 non-null     object
#  6   prec        60 non-null     object
#  7   tmin        60 non-null     object
#  8   tmax        60 non-null     object
#  9   sol         60 non-null     object
# dtypes: object(10)
# memory usage: 4.8+ KB

# %%
df_prueba_1=pd.DataFrame(respuesta_j)
df_prueba_1
# Out:
#          fecha indicativo    nombre provincia altitud  tmed prec  tmin  tmax  \
# 0   2019-02-01       8416  VALÈNCIA  VALENCIA      11  17,6  0,0  16,5  18,7
# 1   2019-02-02       8416  VALÈNCIA  VALENCIA      11  13,4  0,0   9,8  17,1
# 2   2019-02-03       8416  VALÈNCIA  VALENCIA      11  10,6  0,0   7,7  13,6
# 3   2019-02-04       8416  VALÈNCIA  VALENCIA      11  10,6  0,0   4,1  17,2
# 4   2019-02-05       8416  VALÈNCIA  VALENCIA      11  14,6  0,0   7,5  21,6
# 5   2019-02-06       8416  VALÈNCIA  VALENCIA      11  14,6  0,0   8,8  20,4
# 6   2019-02-07       8416  VALÈNCIA  VALENCIA      11  15,0  0,0   7,3  22,8
# 7   2019-02-08       8416  VALÈNCIA  VALENCIA      11  12,2  0,0   7,1  17,4
# 8   2019-02-09       8416  VALÈNCIA  VALENCIA      11  13,2  0,0   5,9  20,4
# 9   2019-02-10       8416  VALÈNCIA  VALENCIA      11  14,0  0,0   8,7  19,3
# 10  2019-02-11       8416  VALÈNCIA  VALENCIA      11  14,6  0,0   9,8  19,5
# ...

# %%
respuesta_2 = requests.get("https://opendata.aemet.es/opendata/sh/4b8ea6fe")
respuesta_22 = respuesta_2.json()

# %%
respuesta_222=pd.DataFrame(respuesta_22)
respuesta_222
# Out:
#          fecha indicativo    nombre provincia altitud  tmed prec  tmin  tmax  \
# 0   2019-02-01       8416  VALÈNCIA  VALENCIA      11  17,6  0,0  16,5  18,7
# 1   2019-02-02       8416  VALÈNCIA  VALENCIA      11  13,4  0,0   9,8  17,1
# 2   2019-02-03       8416  VALÈNCIA  VALENCIA      11  10,6  0,0   7,7  13,6
# 3   2019-02-04       8416  VALÈNCIA  VALENCIA      11  10,6  0,0   4,1  17,2
# 4   2019-02-05       8416  VALÈNCIA  VALENCIA      11  14,6  0,0   7,5  21,6
# 5   2019-02-06       8416  VALÈNCIA  VALENCIA      11  14,6  0,0   8,8  20,4
# 6   2019-02-07       8416  VALÈNCIA  VALENCIA      11  15,0  0,0   7,3  22,8
# 7   2019-02-08       8416  VALÈNCIA  VALENCIA      11  12,2  0,0   7,1  17,4
# 8   2019-02-09       8416  VALÈNCIA  VALENCIA      11  13,2  0,0   5,9  20,4
# 9   2019-02-10       8416  VALÈNCIA  VALENCIA      11  14,0  0,0   8,7  19,3
# 10  2019-02-11       8416  VALÈNCIA  VALENCIA      11  14,6  0,0   9,8  19,5
# ...

# %%
lista_req=["https://opendata.aemet.es/opendata/sh/4b8ea6fe","https://opendata.aemet.es/opendata/sh/488d5e3a"]

# %%
for i in range(0,len(lista_req)):
    response = requests.request("GET", url, headers=headers, params=querystring)
    print(type(response))
# Out:
# <class 'requests.models.Response'>
# <class 'requests.models.Response'>

# %%
df_inicial=pd.read_excel("T_Embalses 1988-2023.xlsx")
df= df_inicial.copy()

# %%
df
# Out:
#        AMBITO_NOMBRE EMBALSE_NOMBRE      FECHA AGUA_TOTAL AGUA_ACTUAL  \
# 0             Segura          Argos 2023-01-31      10,00        7,00
# 1              Duero        Cervera 2023-01-31      10,00        4,00
# 2           Guadiana        Cubilar 2023-01-31      10,00        3,00
# 3               Ebro       Guiamets 2023-01-31      10,00        1,00
# 4              Júcar        La Toba 2023-01-31      10,00        8,00
# ...              ...            ...        ...        ...         ...
# 651346          Tajo       Rosarito 1988-01-05      93,00       53,00
# 651347         Duero      Compuerto 1988-01-05      95,00       80,00
# 651348  Guadalquivir        Iznájar 1988-01-05     980,00      363,00
# 651349          Tajo          Aceña 1987-10-13      24,00        2,00
# 651350          Tajo          Aceña 1987-10-06      24,00        1,00
#
#         ELECTRICO_FLAG
# 0                    0
# 1                    0
# 2                    0
# 3                    0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651351 entries, 0 to 651350
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   AMBITO_NOMBRE   651351 non-null  object
#  1   EMBALSE_NOMBRE  651351 non-null  object
#  2   FECHA           651351 non-null  datetime64[ns]
#  3   AGUA_TOTAL      651351 non-null  object
#  4   AGUA_ACTUAL     651351 non-null  object
#  5   ELECTRICO_FLAG  651351 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(4)
# memory usage: 29.8+ MB

# %%
from geopy.geocoders import Nominatim

# %%
 
geolocator = Nominatim()
#location = geolocator.geocode("175 5th Avenue NYC")
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Input In [61], in <cell line: 1>()
# ----> 1 geolocator = Nominatim()
#
# File ~\Anaconda3\lib\site-packages\geopy\geocoders\nominatim.py:105, in Nominatim.__init__(self, timeout, proxies, domain, scheme, user_agent, ssl_context, adapter_factory)
#     101 self.domain = domain.strip('/')
#     103 if (self.domain == _DEFAULT_NOMINATIM_DOMAIN
#     104         and self.headers['User-Agent'] in _REJECTED_USER_AGENTS):
# --> 105     raise ConfigurationError(
#     106         'Using Nominatim with default or sample `user_agent` "%s" is '
#     107         'strongly discouraged, as it violates Nominatim\'s ToS '
#     108         'https://operations.osmfoundation.org/policies/nominatim/ '
#     109         'and may possibly cause 403 and 429 HTTP errors. '
#     110         'Please specify a custom `user_agent` with '
# ...
